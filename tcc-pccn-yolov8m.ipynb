# %% [markdown]
# # Treinamento usando YOLOv8m

# %% [markdown]
# ### Dados

# %%
#!pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Z1wyDWMNAv21MSTpQuY6")
project = rf.workspace("glucoocr").project("glycometre-fi2xq")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %% [markdown]
# ### Treino

# %%
from ultralytics import YOLO

model = YOLO("yolov8m.pt")
model.train(data=f"glycometre-2/data.yaml", device=0, epochs=50, imgsz=640)
# Out:
# New https://pypi.org/project/ultralytics/8.3.167 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.166  Python-3.12.6 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3060, 12287MiB)
# ...

# %% [markdown]
# ### Validação

# %%
metrics = model.val(data=f"glycometre-2/data.yaml", split="test")
metrics.box.map50  # mAP@0.5
# Out:
# Ultralytics 8.3.166  Python-3.12.6 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3060, 12287MiB)
# Model summary (fused): 92 layers, 25,848,445 parameters, 0 gradients, 78.7 GFLOPs
# val: Fast image access  (ping: 0.30.0 ms, read: 5.32.7 MB/s, size: 41.9 KB)
# val: Scanning E:\tcc-yolo\glycometre-2\test\labels.cache... 722 images, 0 backgrounds, 0 corrupt: 100%|██████████| 722/722 [00:00<?, ?it/s]
# WARNING Box and segment counts should be equal, but got len(segments) = 844, len(boxes) = 3500. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 46/46 [00:16<00:00,  2.75it/s]
#                    all        722       3500      0.943      0.967      0.975      0.811
#                      0        147        164      0.966      0.994      0.995      0.883
# ...

# %% [markdown]
# ### Metricas

# %% [markdown]
# PRINTAR METRICAS E GRAFICOS

# %%
import pandas as pd

caminho_csv = "runs/detect/train5/results.csv"
df = pd.read_csv(caminho_csv)
df.tail()  # Mostra as últimas epochs
# Out:
#     epoch     time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 45     46  20819.1         0.63493         0.29878         0.97387
# 46     47  21285.5         0.62841         0.29412         0.97011
# 47     48  21773.2         0.62298         0.29048         0.96713
# 48     49  22231.8         0.61926         0.28637         0.96472
# 49     50  22691.2         0.61395         0.28370         0.96200
#
#     metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 45               0.94304            0.93207           0.94934
# 46               0.94406            0.92981           0.94908
# 47               0.94324            0.93129           0.94917
# 48               0.93804            0.93423           0.95004
# 49               0.94106            0.93413           0.94986
#
#     metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 45              0.79744       0.65040       0.31556       0.95002  0.001090
# ...

# %% [markdown]
# #### Labels

# %%
from IPython.display import Image, display
import os

# %%
display(Image(filename="runs/detect/train5/labels.jpg"))

# %% [markdown]
# #### Resultados

# %%
display(Image(filename="runs/detect/train5/results.png"))

# %% [markdown]
# #### Matriz de Confusão

# %%
display(Image(filename="runs/detect/train5/confusion_matrix.png"))

# %% [markdown]
# #### Precision-recall

# %%
display(Image(filename="runs/detect/train5/BoxPR_curve.png"))

# %% [markdown]
# #### Recall-confidence

# %%
display(Image(filename="runs/detect/train5/BoxR_curve.png"))

# %% [markdown]
# #### F1

# %%
display(Image(filename="runs/detect/train5/BoxF1_curve.png"))

# %% [markdown]
# ####

# %% [markdown]
# #### Precision-confidence

# %%
display(Image(filename="runs/detect/train5/BoxP_curve.png"))
